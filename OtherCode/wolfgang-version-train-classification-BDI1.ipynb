# %%
import torch
print(torch.__version__)
# Out:
# 1.7.1

# %%
from __future__ import print_function

import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision import models
import numpy
import dataset
import random
from utils import *
from VGG_gru import FERANet
# from tensorboardX import SummaryWriter
import argparse
import subprocess
import math

# %%
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"

description='PyTorch Facial Expression'
batch_size = 1
epochs = 20 #120
length = 32
preInitial = True
# dataset = 'Emotiw'

# %%
trn= "BDItrain1.txt"
vl= "BDIval1.txt"
tst= "BDItest1.txt"

# %%
trainlist = "/home/duaa/Desktop/GRU-test/emotion_classification-master/VGG_GRU/TrainTestlist/Emotiw/"+trn
vallist =  "/home/duaa/Desktop/GRU-test/emotion_classification-master/VGG_GRU/TrainTestlist/Emotiw/"+vl
testlist =  "/home/duaa/Desktop/GRU-test/emotion_classification-master/VGG_GRU/TrainTestlist/Emotiw/"+tst

# %%
print(trainlist)
# Out:
# /home/duaa/Desktop/GRU-test/emotion_classification-master/VGG_GRU/TrainTestlist/Emotiw/BDItrain1.txt

# %%
path_d= "/home/duaa/Desktop/GRU-test/emotion_classification-master/VGG_GRU/dataset.py"

# %%
if os.path.isfile != True:
	subprocess.call(["python", path_d])

# %%
# if os.path.isfile != True:
# 	subprocess.call(["python", "./TrainTestlist/"+dataset+"/getTraintest_"+dataset+".py"])

# %%
backupdir     = "/tmp/duaa/GRU"
batch_size    = 1
# learning_rate = 0.00001
learning_rate = 0.0001

# accuracy = 0.
# best_accuracy = 0.
metric = AccumulatedAccuracyMetric()

####here for same result#####
num_workers   = 0
# torch.backends.cudnn.enabled = False
torch.manual_seed(1)
torch.cuda.manual_seed(1)
random.seed(1)
torch.backends.cudnn.benchmark = True
# torch.backends.cudnn.deterministic = True

# %%
if preInitial == True:
	model = FERANet()
	model = Initial(model)
else:
	model = FERANet()
# Out:
# start loading vgg16 pre-fera2013 model...
# finish loading vgg16 pre-fera2013 model!

# %%
processed_batches = 0
kwargs = {'num_workers': num_workers, 'pin_memory': True}
model = model.cuda()


optimizer = optim.SGD(model.parameters(), lr=learning_rate , momentum=0.9, weight_decay= 0.00005)

# loss_function = nn.CrossEntropyLoss()
loss_function = nn.L1Loss()

use_Tensorboard = False

# %%
def train(epoch,optimizer):


	train_loader = torch.utils.data.DataLoader(
		dataset.listDataset(trainlist,length = length,
					   shuffle=True,
					   train=True,
					   dataset = dataset),
		batch_size=batch_size, shuffle=False, **kwargs)


	for param_group in optimizer.param_groups:
		train_learning_rate = float(param_group['lr'])

	logging('epoch %d, processed %d samples, lr %f' % (epoch, epoch * len(train_loader.dataset), train_learning_rate))

	running_loss = 0.0

	model.train()

	for batch_idx, (data, label) in enumerate(train_loader):


		data = data.squeeze(0)
		data = Variable(data).cuda()

		label = Variable(label.long()).cuda()
		label = label.squeeze(1)

		optimizer.zero_grad()

		output = model(data)

		loss = loss_function(output, label)

		running_loss += loss.data

		loss.backward()

		optimizer.step()

	if epoch %1 == 0:
		logging('Loss:{:.6f}'.format(running_loss))

# %%
def eval(epoch,metric):

	model.eval()

# 	global best_accuracy
# 	global accuracy

	metric.reset()
    
	accuracy = 0.
	best_accuracy = 0.
    
	test_loader = torch.utils.data.DataLoader(
# 		dataset.listDataset(vallist,length = length,
		dataset.listDataset(vallist,length = length,        
					shuffle=False,
					train=False,
					dataset = dataset),
					batch_size=1, shuffle=False, **kwargs)


	for batch_idx, (data, label) in enumerate(test_loader):

		data = data.squeeze(0)

		Batch,T,C,H,W = data.size()

		data = Variable(data,volatile=True).cuda()

		label = Variable(label.long(),volatile=True).cuda()
		label = label.squeeze(1)
# 		print('label')
		output = []
		for batch_index in range(Batch):
# 			print(batch_index)            
			output_feature = model(data[batch_index])

			output.append(output_feature)

		output = torch.mean(torch.cat(output), 0, keepdim=True)
        
		print("Dua's output is: ", output)
		metric(output, label) 
# 		print(metric.value())

		accuracy, eval_loss = metric.value()
# 		print("Dua's test is: ",accuracy)

        
	if accuracy >= best_accuracy:
		best_accuracy = accuracy
		print("saving accuracy is: ",accuracy)
		torch.save(model.state_dict(),'%s/model_%d.pkl' % (backupdir,epoch))

	logging("test accuracy: %f" % (accuracy))
	logging("best accuracy: %f" % (best_accuracy))

	return accuracy

# %%
def test(epoch,metric):

	model.eval()

# 	global best_accuracy
# 	global accuracy

	metric.reset()
    
	accuracy = 0.
	best_accuracy = 0.
    
	test_loader = torch.utils.data.DataLoader(
# 		dataset.listDataset(vallist,length = length,
		dataset.listDataset(testlist,length = length,        
					shuffle=False,
					train=False,
					dataset = dataset),
					batch_size=1, shuffle=False, **kwargs)


	for batch_idx, (data, label) in enumerate(test_loader):

		data = data.squeeze(0)

		Batch,T,C,H,W = data.size()

		data = Variable(data,volatile=True).cuda()

		label = Variable(label.long(),volatile=True).cuda()
		label = label.squeeze(1)
# 		print('label')
		output = []
		for batch_index in range(Batch):
# 			print(batch_index)            
			output_feature = model(data[batch_index])

			output.append(output_feature)

		output = torch.mean(torch.cat(output), 0, keepdim=True)
        

		metric(output, label) 
# 		print(metric.value())

		accuracy, eval_loss = metric.value()
# 		print(accuracy)

        
	if accuracy >= best_accuracy:
		best_accuracy = accuracy
# 		print("saving accuracy is: ",accuracy)
# 		torch.save(model.state_dict(),'%s/model_%d.pkl' % (backupdir,epoch))

	logging("test accuracy: %f" % (accuracy))
	logging("best accuracy: %f" % (best_accuracy))

	return accuracy

# %%
for epoch in range(1, epochs+1): 

	train(epoch,optimizer)
	with torch.no_grad():
		eval_accuary = eval(epoch,metric)
# Out:
# 2021-02-05 00:28:54 epoch 1, processed 36 samples, lr 0.000100
# /home/duaa/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/loss.py:94: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# 2021-02-05 00:29:06 Loss:338.842773
# /home/duaa/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/duaa/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Dua's output is:  tensor([[0.3145]], device='cuda:0')
# Dua's output is:  tensor([[0.2827]], device='cuda:0')
# Dua's output is:  tensor([[0.4047]], device='cuda:0')
# Dua's output is:  tensor([[-0.1448]], device='cuda:0')
# Dua's output is:  tensor([[0.0610]], device='cuda:0')
# Dua's output is:  tensor([[-0.0632]], device='cuda:0')
# Dua's output is:  tensor([[0.3515]], device='cuda:0')
# Dua's output is:  tensor([[0.6722]], device='cuda:0')
# Dua's output is:  tensor([[0.6167]], device='cuda:0')
# Dua's output is:  tensor([[0.4644]], device='cuda:0')
# Dua's output is:  tensor([[0.4866]], device='cuda:0')
# Dua's output is:  tensor([[0.2583]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:31:51 test accuracy: 0.500000
# 2021-02-05 00:31:51 best accuracy: 0.500000
# 2021-02-05 00:31:51 epoch 2, processed 72 samples, lr 0.000100
# 2021-02-05 00:32:00 Loss:335.167755
# Dua's output is:  tensor([[0.4665]], device='cuda:0')
# Dua's output is:  tensor([[0.5461]], device='cuda:0')
# Dua's output is:  tensor([[0.7451]], device='cuda:0')
# Dua's output is:  tensor([[-0.0655]], device='cuda:0')
# Dua's output is:  tensor([[0.4937]], device='cuda:0')
# Dua's output is:  tensor([[0.1141]], device='cuda:0')
# Dua's output is:  tensor([[0.6874]], device='cuda:0')
# Dua's output is:  tensor([[1.0296]], device='cuda:0')
# Dua's output is:  tensor([[0.7770]], device='cuda:0')
# Dua's output is:  tensor([[0.8304]], device='cuda:0')
# Dua's output is:  tensor([[1.0275]], device='cuda:0')
# Dua's output is:  tensor([[0.2908]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:34:42 test accuracy: 0.500000
# 2021-02-05 00:34:42 best accuracy: 0.500000
# 2021-02-05 00:34:42 epoch 3, processed 108 samples, lr 0.000100
# 2021-02-05 00:34:52 Loss:327.767548
# Dua's output is:  tensor([[0.0600]], device='cuda:0')
# Dua's output is:  tensor([[0.2611]], device='cuda:0')
# Dua's output is:  tensor([[0.3557]], device='cuda:0')
# Dua's output is:  tensor([[-0.4812]], device='cuda:0')
# Dua's output is:  tensor([[0.4119]], device='cuda:0')
# Dua's output is:  tensor([[-0.2099]], device='cuda:0')
# Dua's output is:  tensor([[0.5983]], device='cuda:0')
# Dua's output is:  tensor([[0.9589]], device='cuda:0')
# Dua's output is:  tensor([[0.8720]], device='cuda:0')
# Dua's output is:  tensor([[0.9137]], device='cuda:0')
# Dua's output is:  tensor([[1.0165]], device='cuda:0')
# Dua's output is:  tensor([[-0.2196]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:37:36 test accuracy: 0.500000
# 2021-02-05 00:37:36 best accuracy: 0.500000
# 2021-02-05 00:37:36 epoch 4, processed 144 samples, lr 0.000100
# 2021-02-05 00:37:46 Loss:319.805634
# Dua's output is:  tensor([[0.4445]], device='cuda:0')
# Dua's output is:  tensor([[0.8325]], device='cuda:0')
# Dua's output is:  tensor([[0.8231]], device='cuda:0')
# Dua's output is:  tensor([[-0.1833]], device='cuda:0')
# Dua's output is:  tensor([[1.1184]], device='cuda:0')
# Dua's output is:  tensor([[0.2985]], device='cuda:0')
# Dua's output is:  tensor([[1.4106]], device='cuda:0')
# Dua's output is:  tensor([[1.5498]], device='cuda:0')
# Dua's output is:  tensor([[1.3370]], device='cuda:0')
# Dua's output is:  tensor([[1.5901]], device='cuda:0')
# Dua's output is:  tensor([[1.6600]], device='cuda:0')
# Dua's output is:  tensor([[0.1795]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:40:29 test accuracy: 0.500000
# 2021-02-05 00:40:29 best accuracy: 0.500000
# 2021-02-05 00:40:29 epoch 5, processed 180 samples, lr 0.000100
# 2021-02-05 00:40:40 Loss:319.539490
# Dua's output is:  tensor([[0.4951]], device='cuda:0')
# Dua's output is:  tensor([[1.0719]], device='cuda:0')
# Dua's output is:  tensor([[0.6999]], device='cuda:0')
# Dua's output is:  tensor([[-0.3281]], device='cuda:0')
# Dua's output is:  tensor([[1.0484]], device='cuda:0')
# Dua's output is:  tensor([[-0.0363]], device='cuda:0')
# Dua's output is:  tensor([[1.2887]], device='cuda:0')
# Dua's output is:  tensor([[1.7826]], device='cuda:0')
# Dua's output is:  tensor([[1.5722]], device='cuda:0')
# Dua's output is:  tensor([[1.6988]], device='cuda:0')
# Dua's output is:  tensor([[1.8906]], device='cuda:0')
# Dua's output is:  tensor([[0.1849]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:43:24 test accuracy: 0.500000
# 2021-02-05 00:43:24 best accuracy: 0.500000
# 2021-02-05 00:43:24 epoch 6, processed 216 samples, lr 0.000100
# 2021-02-05 00:43:34 Loss:313.307892
# Dua's output is:  tensor([[1.0747]], device='cuda:0')
# Dua's output is:  tensor([[1.6722]], device='cuda:0')
# Dua's output is:  tensor([[1.7217]], device='cuda:0')
# Dua's output is:  tensor([[0.0004]], device='cuda:0')
# Dua's output is:  tensor([[1.5547]], device='cuda:0')
# Dua's output is:  tensor([[0.3397]], device='cuda:0')
# Dua's output is:  tensor([[2.0722]], device='cuda:0')
# Dua's output is:  tensor([[2.3364]], device='cuda:0')
# Dua's output is:  tensor([[2.0346]], device='cuda:0')
# Dua's output is:  tensor([[2.0919]], device='cuda:0')
# Dua's output is:  tensor([[2.3915]], device='cuda:0')
# Dua's output is:  tensor([[0.3645]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:46:17 test accuracy: 0.500000
# 2021-02-05 00:46:17 best accuracy: 0.500000
# 2021-02-05 00:46:17 epoch 7, processed 252 samples, lr 0.000100
# 2021-02-05 00:46:27 Loss:304.320496
# Dua's output is:  tensor([[0.6364]], device='cuda:0')
# Dua's output is:  tensor([[0.8792]], device='cuda:0')
# Dua's output is:  tensor([[0.4668]], device='cuda:0')
# Dua's output is:  tensor([[-0.3726]], device='cuda:0')
# Dua's output is:  tensor([[1.2402]], device='cuda:0')
# Dua's output is:  tensor([[-0.2139]], device='cuda:0')
# Dua's output is:  tensor([[1.9117]], device='cuda:0')
# Dua's output is:  tensor([[2.1469]], device='cuda:0')
# Dua's output is:  tensor([[1.7908]], device='cuda:0')
# Dua's output is:  tensor([[2.3598]], device='cuda:0')
# Dua's output is:  tensor([[2.3618]], device='cuda:0')
# Dua's output is:  tensor([[-0.1244]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:49:10 test accuracy: 0.500000
# 2021-02-05 00:49:10 best accuracy: 0.500000
# 2021-02-05 00:49:10 epoch 8, processed 288 samples, lr 0.000100
# 2021-02-05 00:49:20 Loss:297.500214
# Dua's output is:  tensor([[1.3788]], device='cuda:0')
# Dua's output is:  tensor([[2.0467]], device='cuda:0')
# Dua's output is:  tensor([[1.0648]], device='cuda:0')
# Dua's output is:  tensor([[-0.3119]], device='cuda:0')
# Dua's output is:  tensor([[2.2633]], device='cuda:0')
# Dua's output is:  tensor([[-0.0969]], device='cuda:0')
# Dua's output is:  tensor([[2.9946]], device='cuda:0')
# Dua's output is:  tensor([[2.9185]], device='cuda:0')
# Dua's output is:  tensor([[2.8901]], device='cuda:0')
# Dua's output is:  tensor([[2.9552]], device='cuda:0')
# Dua's output is:  tensor([[3.3111]], device='cuda:0')
# Dua's output is:  tensor([[0.1539]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:52:03 test accuracy: 0.500000
# 2021-02-05 00:52:03 best accuracy: 0.500000
# 2021-02-05 00:52:03 epoch 9, processed 324 samples, lr 0.000100
# 2021-02-05 00:52:14 Loss:292.063354
# Dua's output is:  tensor([[2.9646]], device='cuda:0')
# Dua's output is:  tensor([[3.2932]], device='cuda:0')
# Dua's output is:  tensor([[2.5268]], device='cuda:0')
# Dua's output is:  tensor([[0.6455]], device='cuda:0')
# Dua's output is:  tensor([[3.5403]], device='cuda:0')
# Dua's output is:  tensor([[0.8771]], device='cuda:0')
# Dua's output is:  tensor([[4.0201]], device='cuda:0')
# Dua's output is:  tensor([[3.9431]], device='cuda:0')
# Dua's output is:  tensor([[3.6649]], device='cuda:0')
# Dua's output is:  tensor([[3.7276]], device='cuda:0')
# Dua's output is:  tensor([[4.1333]], device='cuda:0')
# Dua's output is:  tensor([[1.2656]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:54:57 test accuracy: 0.500000
# 2021-02-05 00:54:57 best accuracy: 0.500000
# 2021-02-05 00:54:57 epoch 10, processed 360 samples, lr 0.000100
# 2021-02-05 00:55:09 Loss:285.277191
# Dua's output is:  tensor([[1.2847]], device='cuda:0')
# Dua's output is:  tensor([[2.4634]], device='cuda:0')
# Dua's output is:  tensor([[1.2818]], device='cuda:0')
# Dua's output is:  tensor([[-0.0802]], device='cuda:0')
# Dua's output is:  tensor([[3.3220]], device='cuda:0')
# Dua's output is:  tensor([[0.1481]], device='cuda:0')
# Dua's output is:  tensor([[4.2222]], device='cuda:0')
# Dua's output is:  tensor([[4.1099]], device='cuda:0')
# Dua's output is:  tensor([[3.7479]], device='cuda:0')
# Dua's output is:  tensor([[3.9315]], device='cuda:0')
# Dua's output is:  tensor([[4.4384]], device='cuda:0')
# Dua's output is:  tensor([[0.0832]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 00:57:51 test accuracy: 0.500000
# 2021-02-05 00:57:51 best accuracy: 0.500000
# 2021-02-05 00:57:51 epoch 11, processed 396 samples, lr 0.000100
# 2021-02-05 00:58:01 Loss:269.640503
# Dua's output is:  tensor([[0.8058]], device='cuda:0')
# Dua's output is:  tensor([[1.6042]], device='cuda:0')
# Dua's output is:  tensor([[-0.0569]], device='cuda:0')
# Dua's output is:  tensor([[-0.2099]], device='cuda:0')
# Dua's output is:  tensor([[2.7869]], device='cuda:0')
# Dua's output is:  tensor([[-0.1863]], device='cuda:0')
# Dua's output is:  tensor([[3.3598]], device='cuda:0')
# Dua's output is:  tensor([[3.2224]], device='cuda:0')
# Dua's output is:  tensor([[3.2408]], device='cuda:0')
# Dua's output is:  tensor([[4.4081]], device='cuda:0')
# Dua's output is:  tensor([[4.9067]], device='cuda:0')
# Dua's output is:  tensor([[-0.0352]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:00:44 test accuracy: 0.500000
# 2021-02-05 01:00:44 best accuracy: 0.500000
# 2021-02-05 01:00:44 epoch 12, processed 432 samples, lr 0.000100
# 2021-02-05 01:00:55 Loss:258.994385
# Dua's output is:  tensor([[-0.3370]], device='cuda:0')
# Dua's output is:  tensor([[0.7608]], device='cuda:0')
# Dua's output is:  tensor([[-0.5913]], device='cuda:0')
# Dua's output is:  tensor([[-0.6150]], device='cuda:0')
# Dua's output is:  tensor([[1.2028]], device='cuda:0')
# Dua's output is:  tensor([[-0.4530]], device='cuda:0')
# Dua's output is:  tensor([[1.1135]], device='cuda:0')
# Dua's output is:  tensor([[2.1027]], device='cuda:0')
# Dua's output is:  tensor([[2.5997]], device='cuda:0')
# Dua's output is:  tensor([[4.7726]], device='cuda:0')
# Dua's output is:  tensor([[5.1898]], device='cuda:0')
# Dua's output is:  tensor([[-0.4951]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:03:39 test accuracy: 0.500000
# 2021-02-05 01:03:39 best accuracy: 0.500000
# 2021-02-05 01:03:39 epoch 13, processed 468 samples, lr 0.000100
# 2021-02-05 01:03:49 Loss:248.083893
# Dua's output is:  tensor([[1.5287]], device='cuda:0')
# Dua's output is:  tensor([[2.1722]], device='cuda:0')
# Dua's output is:  tensor([[0.1253]], device='cuda:0')
# Dua's output is:  tensor([[-0.0255]], device='cuda:0')
# Dua's output is:  tensor([[2.6119]], device='cuda:0')
# Dua's output is:  tensor([[-0.1141]], device='cuda:0')
# Dua's output is:  tensor([[3.2982]], device='cuda:0')
# Dua's output is:  tensor([[3.5276]], device='cuda:0')
# Dua's output is:  tensor([[4.9950]], device='cuda:0')
# Dua's output is:  tensor([[5.8242]], device='cuda:0')
# Dua's output is:  tensor([[6.0309]], device='cuda:0')
# Dua's output is:  tensor([[0.2039]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:06:32 test accuracy: 0.500000
# 2021-02-05 01:06:32 best accuracy: 0.500000
# 2021-02-05 01:06:32 epoch 14, processed 504 samples, lr 0.000100
# 2021-02-05 01:06:43 Loss:233.990692
# Dua's output is:  tensor([[1.5288]], device='cuda:0')
# Dua's output is:  tensor([[3.3753]], device='cuda:0')
# Dua's output is:  tensor([[-0.0671]], device='cuda:0')
# Dua's output is:  tensor([[-0.2996]], device='cuda:0')
# Dua's output is:  tensor([[3.3547]], device='cuda:0')
# Dua's output is:  tensor([[-0.1675]], device='cuda:0')
# Dua's output is:  tensor([[6.0073]], device='cuda:0')
# Dua's output is:  tensor([[6.4357]], device='cuda:0')
# Dua's output is:  tensor([[5.2099]], device='cuda:0')
# Dua's output is:  tensor([[6.6368]], device='cuda:0')
# Dua's output is:  tensor([[7.0316]], device='cuda:0')
# Dua's output is:  tensor([[-0.0038]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:09:27 test accuracy: 0.500000
# 2021-02-05 01:09:27 best accuracy: 0.500000
# 2021-02-05 01:09:27 epoch 15, processed 540 samples, lr 0.000100
# 2021-02-05 01:09:38 Loss:214.936050
# Dua's output is:  tensor([[0.1142]], device='cuda:0')
# Dua's output is:  tensor([[3.0937]], device='cuda:0')
# Dua's output is:  tensor([[-0.1224]], device='cuda:0')
# Dua's output is:  tensor([[-0.0896]], device='cuda:0')
# Dua's output is:  tensor([[3.8408]], device='cuda:0')
# Dua's output is:  tensor([[-0.1388]], device='cuda:0')
# Dua's output is:  tensor([[5.0717]], device='cuda:0')
# Dua's output is:  tensor([[6.9682]], device='cuda:0')
# Dua's output is:  tensor([[5.4855]], device='cuda:0')
# Dua's output is:  tensor([[7.1705]], device='cuda:0')
# Dua's output is:  tensor([[7.8084]], device='cuda:0')
# Dua's output is:  tensor([[-0.2053]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:12:21 test accuracy: 0.500000
# 2021-02-05 01:12:21 best accuracy: 0.500000
# 2021-02-05 01:12:21 epoch 16, processed 576 samples, lr 0.000100
# 2021-02-05 01:12:32 Loss:196.386185
# Dua's output is:  tensor([[3.0089]], device='cuda:0')
# Dua's output is:  tensor([[6.5057]], device='cuda:0')
# Dua's output is:  tensor([[0.8463]], device='cuda:0')
# Dua's output is:  tensor([[0.9276]], device='cuda:0')
# Dua's output is:  tensor([[7.1388]], device='cuda:0')
# Dua's output is:  tensor([[0.4997]], device='cuda:0')
# Dua's output is:  tensor([[8.6644]], device='cuda:0')
# Dua's output is:  tensor([[8.9190]], device='cuda:0')
# Dua's output is:  tensor([[8.2211]], device='cuda:0')
# Dua's output is:  tensor([[8.4694]], device='cuda:0')
# Dua's output is:  tensor([[9.1227]], device='cuda:0')
# Dua's output is:  tensor([[1.7466]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:15:15 test accuracy: 0.500000
# 2021-02-05 01:15:15 best accuracy: 0.500000
# 2021-02-05 01:15:15 epoch 17, processed 612 samples, lr 0.000100
# 2021-02-05 01:15:26 Loss:196.981552
# Dua's output is:  tensor([[0.1023]], device='cuda:0')
# Dua's output is:  tensor([[0.8671]], device='cuda:0')
# Dua's output is:  tensor([[-0.5762]], device='cuda:0')
# Dua's output is:  tensor([[-0.5572]], device='cuda:0')
# Dua's output is:  tensor([[3.5830]], device='cuda:0')
# Dua's output is:  tensor([[-0.3645]], device='cuda:0')
# Dua's output is:  tensor([[5.0296]], device='cuda:0')
# Dua's output is:  tensor([[6.6005]], device='cuda:0')
# Dua's output is:  tensor([[3.9262]], device='cuda:0')
# Dua's output is:  tensor([[8.7444]], device='cuda:0')
# Dua's output is:  tensor([[9.5817]], device='cuda:0')
# Dua's output is:  tensor([[-0.3577]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:18:09 test accuracy: 0.500000
# 2021-02-05 01:18:09 best accuracy: 0.500000
# 2021-02-05 01:18:09 epoch 18, processed 648 samples, lr 0.000100
# 2021-02-05 01:18:21 Loss:169.316177
# Dua's output is:  tensor([[-0.2579]], device='cuda:0')
# Dua's output is:  tensor([[0.4978]], device='cuda:0')
# Dua's output is:  tensor([[-0.6943]], device='cuda:0')
# Dua's output is:  tensor([[-0.5494]], device='cuda:0')
# Dua's output is:  tensor([[3.7138]], device='cuda:0')
# Dua's output is:  tensor([[-0.4370]], device='cuda:0')
# Dua's output is:  tensor([[5.0149]], device='cuda:0')
# Dua's output is:  tensor([[4.3459]], device='cuda:0')
# Dua's output is:  tensor([[2.9666]], device='cuda:0')
# Dua's output is:  tensor([[9.4120]], device='cuda:0')
# Dua's output is:  tensor([[10.4168]], device='cuda:0')
# Dua's output is:  tensor([[-0.5046]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:21:04 test accuracy: 0.500000
# 2021-02-05 01:21:04 best accuracy: 0.500000
# 2021-02-05 01:21:04 epoch 19, processed 684 samples, lr 0.000100
# 2021-02-05 01:21:15 Loss:152.648743
# Dua's output is:  tensor([[0.0260]], device='cuda:0')
# Dua's output is:  tensor([[0.1325]], device='cuda:0')
# Dua's output is:  tensor([[-0.4961]], device='cuda:0')
# Dua's output is:  tensor([[-0.3975]], device='cuda:0')
# Dua's output is:  tensor([[1.5285]], device='cuda:0')
# Dua's output is:  tensor([[-0.2146]], device='cuda:0')
# Dua's output is:  tensor([[0.3988]], device='cuda:0')
# Dua's output is:  tensor([[1.2878]], device='cuda:0')
# Dua's output is:  tensor([[0.6973]], device='cuda:0')
# Dua's output is:  tensor([[9.3706]], device='cuda:0')
# Dua's output is:  tensor([[10.5242]], device='cuda:0')
# Dua's output is:  tensor([[-0.0240]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:23:59 test accuracy: 0.500000
# 2021-02-05 01:23:59 best accuracy: 0.500000
# 2021-02-05 01:23:59 epoch 20, processed 720 samples, lr 0.000100
# 2021-02-05 01:24:10 Loss:151.567047
# Dua's output is:  tensor([[0.3628]], device='cuda:0')
# Dua's output is:  tensor([[5.5874]], device='cuda:0')
# Dua's output is:  tensor([[2.8946]], device='cuda:0')
# Dua's output is:  tensor([[0.3136]], device='cuda:0')
# Dua's output is:  tensor([[8.7358]], device='cuda:0')
# Dua's output is:  tensor([[1.8739]], device='cuda:0')
# Dua's output is:  tensor([[11.7090]], device='cuda:0')
# Dua's output is:  tensor([[11.2828]], device='cuda:0')
# Dua's output is:  tensor([[11.0638]], device='cuda:0')
# Dua's output is:  tensor([[11.8591]], device='cuda:0')
# Dua's output is:  tensor([[12.6675]], device='cuda:0')
# Dua's output is:  tensor([[0.6498]], device='cuda:0')
# saving accuracy is:  0.5
# 2021-02-05 01:26:54 test accuracy: 0.500000
# 2021-02-05 01:26:54 best accuracy: 0.500000

# %%
for epoch in range(1, epochs+1): 
	with torch.no_grad():
		eval_accuary = test(epoch,metric)
# Out:
# /home/duaa/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/duaa/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# 2021-02-05 01:29:45 test accuracy: 0.500000
# 2021-02-05 01:29:45 best accuracy: 0.500000
# 2021-02-05 01:32:37 test accuracy: 0.500000
# 2021-02-05 01:32:37 best accuracy: 0.500000
# 2021-02-05 01:35:27 test accuracy: 0.500000
# 2021-02-05 01:35:27 best accuracy: 0.500000
# 2021-02-05 01:38:19 test accuracy: 0.500000
# 2021-02-05 01:38:19 best accuracy: 0.500000
# 2021-02-05 01:41:20 test accuracy: 0.500000
# 2021-02-05 01:41:20 best accuracy: 0.500000
# 2021-02-05 01:51:14 test accuracy: 0.500000
# 2021-02-05 01:51:14 best accuracy: 0.500000
# 2021-02-05 01:59:09 test accuracy: 0.500000
# 2021-02-05 01:59:09 best accuracy: 0.500000
# 2021-02-05 02:06:54 test accuracy: 0.500000
# 2021-02-05 02:06:54 best accuracy: 0.500000
# 2021-02-05 02:16:04 test accuracy: 0.500000
# 2021-02-05 02:16:04 best accuracy: 0.500000
# 2021-02-05 02:18:56 test accuracy: 0.500000
# 2021-02-05 02:18:56 best accuracy: 0.500000
# 2021-02-05 02:21:46 test accuracy: 0.500000
# 2021-02-05 02:21:46 best accuracy: 0.500000
# 2021-02-05 02:24:37 test accuracy: 0.500000
# 2021-02-05 02:24:37 best accuracy: 0.500000
# 2021-02-05 02:27:29 test accuracy: 0.500000
# 2021-02-05 02:27:29 best accuracy: 0.500000
# 2021-02-05 02:30:20 test accuracy: 0.500000
# 2021-02-05 02:30:20 best accuracy: 0.500000
# 2021-02-05 02:33:11 test accuracy: 0.500000
# 2021-02-05 02:33:11 best accuracy: 0.500000
# 2021-02-05 02:36:05 test accuracy: 0.500000
# 2021-02-05 02:36:05 best accuracy: 0.500000
# 2021-02-05 02:38:56 test accuracy: 0.500000
# 2021-02-05 02:38:56 best accuracy: 0.500000
# 2021-02-05 02:41:45 test accuracy: 0.500000
# 2021-02-05 02:41:45 best accuracy: 0.500000
# 2021-02-05 02:44:37 test accuracy: 0.500000
# 2021-02-05 02:44:37 best accuracy: 0.500000
# 2021-02-05 02:47:27 test accuracy: 0.500000
# 2021-02-05 02:47:27 best accuracy: 0.500000
